# %%
from annotation import *
selector = SelectMission()
selector.render()
#server = pn.serve(selector.render)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-ecc995c627fd> in <module>
# ----> 1 from annotation import *
#       2 selector = SelectMission()
#       3 selector.render()
#       4 #server = pn.serve(selector.render)
#
# ~\Documents\press\PRESS-annotation\github\press_annotation\annotation.py in <module>
#       8 from functools import partial
#       9 import param, panel as pn, holoviews as hv
# ---> 10 from holoviews.operation.datashader import datashade
#      11 from holoviews.streams import Stream
#      12 from bokeh.models import TickFormatter, FuncTickFormatter
#
# ~\Anaconda3\envs\tf2\lib\site-packages\holoviews\operation\datashader.py in <module>
#      10 import pandas as pd
#      11 import xarray as xr
# ---> 12 import datashader as ds
#      13 import datashader.reductions as rd
#      14 import datashader.transfer_functions as tf
#
# ...
